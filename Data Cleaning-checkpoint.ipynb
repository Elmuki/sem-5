# %%
import pandas as pd

# %%
File=pd.read_csv("product_name.csv")

# %%
File
# Out:
#     Unnamed: 0                                               Name  \
# 0            0  Metashot Augmented Reality Bat with Game for T...
# 1            1  SKOG Magnetic LED Mobile Cooler for Gaming Sem...
# 2            2  Intel i5-12400F 4.4 GHz Upto 4.4 GHz LGA1700 S...
# 3            3                 LAPCARE DCX-A101 2 Fan Cooling Pad
# 4            4  AMD Ryzen 3 3200G with Radeon Vega 8 Graphics ...
# 5            5                SpinBot GS-1P  Gaming Accessory Kit
# 6            6  Acer Aspire 7 Intel Core i5 12th Gen 12450H - ...
# 7            7  STRIFF Extended Size(800mmx300mmx3mm)Gaming Mo...
# 8            8  STRIFF Extended Size(800mmx300mmx3mm)Gaming Mo...
# 9            9  Gyanvi Large Gaming , Office Software Excel En...
# 10          10  Bestor Ultra-Low Friction Gaming Mouse Mat, An...
# 11          11  MSI Katana 17 Intel Core i7 13th Gen 13620H - ...
# 12          12  SpinBot IceDot semi-conducter based Mobile Coo...
# ...

# %%
File.drop("Unnamed: 0",axis=1)
# Out:
#                                                  Name  \
# 0   Metashot Augmented Reality Bat with Game for T...
# 1   SKOG Magnetic LED Mobile Cooler for Gaming Sem...
# 2   Intel i5-12400F 4.4 GHz Upto 4.4 GHz LGA1700 S...
# 3                  LAPCARE DCX-A101 2 Fan Cooling Pad
# 4   AMD Ryzen 3 3200G with Radeon Vega 8 Graphics ...
# 5                 SpinBot GS-1P  Gaming Accessory Kit
# 6   Acer Aspire 7 Intel Core i5 12th Gen 12450H - ...
# 7   STRIFF Extended Size(800mmx300mmx3mm)Gaming Mo...
# 8   STRIFF Extended Size(800mmx300mmx3mm)Gaming Mo...
# 9   Gyanvi Large Gaming , Office Software Excel En...
# 10  Bestor Ultra-Low Friction Gaming Mouse Mat, An...
# 11  MSI Katana 17 Intel Core i7 13th Gen 13620H - ...
# 12  SpinBot IceDot semi-conducter based Mobile Coo...
# 13  SONY PlayStation5 Digital Edition (slim) CFI-2...
# 14  Intel Core i5-10400 10TH GENERATION 3 GHz Upto...
# 15  ASUS TUF Gaming F15 - AI Powered Gaming Intel ...
# ...

# %%
File["price"]=File["price"].str.strip("<a class=""wjcEIp"" href=""/acer-nitro-v-intel-core-i5-13th-gen-13420h-16-gb-512-gb-ssd-windows-11-home-6-graphics-nvidia-geforce-rtx-4050-anv15-51-55b9-gaming-laptop/p/itm967689ee35379?").astype(str)

# %%
File
# Out:
#     Unnamed: 0                                               Name  \
# 0            0  Metashot Augmented Reality Bat with Game for T...
# 1            1  SKOG Magnetic LED Mobile Cooler for Gaming Sem...
# 2            2  Intel i5-12400F 4.4 GHz Upto 4.4 GHz LGA1700 S...
# 3            3                 LAPCARE DCX-A101 2 Fan Cooling Pad
# 4            4  AMD Ryzen 3 3200G with Radeon Vega 8 Graphics ...
# 5            5                SpinBot GS-1P  Gaming Accessory Kit
# 6            6  Acer Aspire 7 Intel Core i5 12th Gen 12450H - ...
# 7            7  STRIFF Extended Size(800mmx300mmx3mm)Gaming Mo...
# 8            8  STRIFF Extended Size(800mmx300mmx3mm)Gaming Mo...
# 9            9  Gyanvi Large Gaming , Office Software Excel En...
# 10          10  Bestor Ultra-Low Friction Gaming Mouse Mat, An...
# 11          11  MSI Katana 17 Intel Core i7 13th Gen 13620H - ...
# 12          12  SpinBot IceDot semi-conducter based Mobile Coo...
# ...

# %%
File.drop("Unnamed: 0",axis=1)
# Out:
#                                                  Name                   price
# 0   Metashot Augmented Reality Bat with Game for T...   "Nx9bqj">₹5,499</div>
# 1   SKOG Magnetic LED Mobile Cooler for Gaming Sem...     "Nx9bqj">₹999</div>
# 2   Intel i5-12400F 4.4 GHz Upto 4.4 GHz LGA1700 S...   "Nx9bqj">₹9,998</div>
# 3                  LAPCARE DCX-A101 2 Fan Cooling Pad     "Nx9bqj">₹599</div>
# 4   AMD Ryzen 3 3200G with Radeon Vega 8 Graphics ...   "Nx9bqj">₹5,690</div>
# 5                 SpinBot GS-1P  Gaming Accessory Kit     "Nx9bqj">₹232</div>
# 6   Acer Aspire 7 Intel Core i5 12th Gen 12450H - ...  "Nx9bqj">₹50,990</div>
# 7   STRIFF Extended Size(800mmx300mmx3mm)Gaming Mo...     "Nx9bqj">₹287</div>
# 8   STRIFF Extended Size(800mmx300mmx3mm)Gaming Mo...     "Nx9bqj">₹226</div>
# 9   Gyanvi Large Gaming , Office Software Excel En...     "Nx9bqj">₹199</div>
# 10  Bestor Ultra-Low Friction Gaming Mouse Mat, An...     "Nx9bqj">₹149</div>
# ...

# %%
File["price"]=File["price"].str.strip('"Nx9bqj">,</div>').astype(str)

# %%
File
# Out:
#     Unnamed: 0                                               Name    price
# 0            0  Metashot Augmented Reality Bat with Game for T...     ₹5,4
# 1            1  SKOG Magnetic LED Mobile Cooler for Gaming Sem...        ₹
# 2            2  Intel i5-12400F 4.4 GHz Upto 4.4 GHz LGA1700 S...   ₹9,998
# 3            3                 LAPCARE DCX-A101 2 Fan Cooling Pad       ₹5
# 4            4  AMD Ryzen 3 3200G with Radeon Vega 8 Graphics ...   ₹5,690
# 5            5                SpinBot GS-1P  Gaming Accessory Kit     ₹232
# 6            6  Acer Aspire 7 Intel Core i5 12th Gen 12450H - ...  ₹50,990
# 7            7  STRIFF Extended Size(800mmx300mmx3mm)Gaming Mo...     ₹287
# 8            8  STRIFF Extended Size(800mmx300mmx3mm)Gaming Mo...     ₹226
# 9            9  Gyanvi Large Gaming , Office Software Excel En...       ₹1
# 10          10  Bestor Ultra-Low Friction Gaming Mouse Mat, An...      ₹14
# ...

# %%
File.drop("Unnamed: 0",axis=1)
# Out:
#                                                  Name    price
# 0   Metashot Augmented Reality Bat with Game for T...     ₹5,4
# 1   SKOG Magnetic LED Mobile Cooler for Gaming Sem...        ₹
# 2   Intel i5-12400F 4.4 GHz Upto 4.4 GHz LGA1700 S...   ₹9,998
# 3                  LAPCARE DCX-A101 2 Fan Cooling Pad       ₹5
# 4   AMD Ryzen 3 3200G with Radeon Vega 8 Graphics ...   ₹5,690
# 5                 SpinBot GS-1P  Gaming Accessory Kit     ₹232
# 6   Acer Aspire 7 Intel Core i5 12th Gen 12450H - ...  ₹50,990
# 7   STRIFF Extended Size(800mmx300mmx3mm)Gaming Mo...     ₹287
# 8   STRIFF Extended Size(800mmx300mmx3mm)Gaming Mo...     ₹226
# 9   Gyanvi Large Gaming , Office Software Excel En...       ₹1
# 10  Bestor Ultra-Low Friction Gaming Mouse Mat, An...      ₹14
# 11  MSI Katana 17 Intel Core i7 13th Gen 13620H - ...  ₹74,990
# 12  SpinBot IceDot semi-conducter based Mobile Coo...     ₹1,4
# 13  SONY PlayStation5 Digital Edition (slim) CFI-2...  ₹44,990
# ...

# %% [markdown]
# # CATAGORICAL DATA

# %%
Salary_Data=pd.DataFrame({"Salary":[10000,20000,30000,40000,50000],"Range":['low','low','mid','mid','high']})

# %%
Salary_Data
# Out:
#    Salary Range
# 0   10000   low
# 1   20000   low
# 2   30000   mid
# 3   40000   mid
# 4   50000  high

# %%
Code=Salary_Data.Range.map({'low':3,'high':1,'mid':2})

# %%
Code
# Out:
# 0    3
# 1    3
# 2    2
# 3    2
# 4    1
# Name: Range, dtype: int64

# %%
publish=pd.DataFrame(Salary_Data['Salary'],columns=['Salary'])

# %%
publish["Code"]=Code

# %%
publish
# Out:
#    Salary  Code
# 0   10000     3
# 1   20000     3
# 2   30000     2
# 3   40000     2
# 4   50000     1
