# %%
import pandas as pd

# %%
data=pd.read_csv("Weather.csv")

# %%
data
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %% [markdown]
# # SCATTER PLOT

# %%
import matplotlib.pyplot as pt
# %matplotlib
# Out:
# Using matplotlib backend: TkAgg

# %%
pt.scatter(data["MinTemp"],data["MaxTemp"])

# %%
dataset=pd.read_csv("2019_nC0v_20200121_20200126_cleaned.csv")

# %%
dataset
# Out:
#      Unnamed: 0 Province/State         Country Date last updated  Confirmed  \
# 0             0       Shanghai  Mainland China         1/21/2020          9
# 1             1         Yunnan  Mainland China         1/21/2020          1
# 2             2        Beijing  Mainland China         1/21/2020         10
# 3             3         Taiwan          Taiwan         1/21/2020          1
# 4             4          Jilin  Mainland China         1/21/2020          0
# ..          ...            ...             ...               ...        ...
# 363         363              0          France   1/26/2020 11:00          3
# 364         364              0       Australia   1/26/2020 11:00          4
# 365         365              0           Nepal   1/26/2020 11:00          1
# 366         366              0        Malaysia   1/26/2020 11:00          4
# 367         367        Ontario          Canada   1/26/2020 11:00          1
#
#      Suspected  Recovered  Deaths
# ...

# %%
pt.scatter(dataset["Confirmed"],dataset["Country"])

# %%
pt.pie(dataset["Confirmed"][:5],labels=dataset["Province/State"][:5])
# Out:
# ([<matplotlib.patches.Wedge at 0x19a05afb890>,
# ...
#  [Text(0.2447730130080499, 1.0724207066739067, 'Shanghai'),
#   Text(-1.0511300959415604, 0.3242306608047521, 'Yunnan'),
#   Text(-0.24477298790623175, -1.0724207124032321, 'Beijing'),
#   Text(1.087713916065691, -0.16394644490515556, 'Taiwan'),
#   Text(1.0999999999999988, 5.149471657675648e-08, 'Jilin')])

# %%
pt.bar(dataset["Province/State"],dataset["Confirmed"])
# Out:
# <BarContainer object of 368 artists>
